# %%
from phi.agent import Agent
from phi.tools.duckduckgo import DuckDuckGo
from phi.model.groq import Groq
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
agent = Agent(tools=[DuckDuckGo()], show_tool_calls=True, model=Groq(id="llama-3.1-8b-instant", api_key=os.getenv("GROQ_API_KEY")),)
agent.print_response("Whats happening in France?")
# Out:
# Output()
# c:\Users\lenovo\anaconda3\envs\agents\Lib\site-packages\phi\tools\duckduckgo.py:65: RuntimeWarning: This package
# (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddgs = DDGS(
# c:\Users\lenovo\anaconda3\envs\agents\Lib\site-packages\phi\tools\duckduckgo.py:86: RuntimeWarning: This package
# (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddgs = DDGS(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
